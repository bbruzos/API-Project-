# %%
import pandas as pd
from pprint import pprint

# %%
state_file = ['Alabama.csv',
          'Arizona.csv',
          'Arkansas.csv',
          'California.csv',
          'Colorado.csv',
          'Connecticut.csv',
          'Delaware.csv',
          'District of Columbia.csv',
          'Florida.csv',
          'Georgia.csv',
          'Hawaii.csv',
          'Idaho.csv',
          'Illinois.csv',
          'Indiana.csv',
          'Iowa.csv',
          'Kansas.csv',
          'Kentucky.csv',
          'Louisiana.csv',
          'Maine.csv',
          'Maryland.csv',
          'Massachusetts.csv',
          'Michigan.csv',
          'Minnesota.csv',
          'Mississippi.csv',
          'Missouri.csv',
          'Montana.csv',
          'Nebraska.csv',
          'Nevada.csv',
          'New Jersey.csv',
          'New York.csv',
          'North Carolina.csv',
          'North Dakota.csv',
          'Ohio.csv',
          'Oklahoma.csv',
          'Oregon.csv',
          'Pennsylvania.csv',
          'South Carolina.csv',
          'Tennessee.csv',
          'Texas.csv',
          'Utah.csv',
          'Virginia.csv',
          'Washington.csv',
          'West Virginia.csv',
          'Wisconsin.csv',
          'Wyoming.csv']

# %%
dataframes = []

# %%
dataframes[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c917901d6ee1> in <module>
# ----> 1 dataframes[0]
#
# IndexError: list index out of range

# %%
#drop_columns = ["Rk", "Yrs", "From", "G", "MP", "FG", "FGA", "3P", "PTS", "FG%","3P%","FT%", "MP.1", "PTS.1", "TRB.1", "AST.1","3PA","FT", "ORB", "TRB","AST","STL", "BLK", "TOV","PF", "FTA"]

col_drop = list(dataframes[0].columns.values)
                   
col_drop.remove("Player")
col_drop.remove("To")
col_drop.remove("Date")
col_drop.remove("City")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-0a34e4e9bf53> in <module>
#       1 #drop_columns = ["Rk", "Yrs", "From", "G", "MP", "FG", "FGA", "3P", "PTS", "FG%","3P%","FT%", "MP.1", "PTS.1", "TRB.1", "AST.1","3PA","FT", "ORB", "TRB","AST","STL", "BLK", "TOV","PF", "FTA"]
#       2
# ----> 3 col_drop = list(dataframes[0].columns.values)
#       4
#       5 col_drop.remove("Player")
#
# IndexError: list index out of range

# %%
x0 = dataframes[0].drop(columns = col_drop)
x1 = dataframes[1].drop(columns = col_drop)
x2 = dataframes[2].drop(columns = col_drop)
x3 = dataframes[3].drop(columns = col_drop)
x4 = dataframes[4].drop(columns = col_drop)
x5 = dataframes[5].drop(columns = col_drop)
x6 = dataframes[6].drop(columns = col_drop)
x7 = dataframes[7].drop(columns = col_drop)
x8 = dataframes[8].drop(columns = col_drop)
x9 = dataframes[9].drop(columns = col_drop)
x10 = dataframes[10].drop(columns = col_drop)
x11 = dataframes[11].drop(columns = col_drop)
x12 = dataframes[12].drop(columns = col_drop)
x13 = dataframes[13].drop(columns = col_drop)
x14 = dataframes[14].drop(columns = col_drop)
x15 = dataframes[15].drop(columns = col_drop)
x16 = dataframes[16].drop(columns = col_drop)
x17 = dataframes[17].drop(columns = col_drop)
x18 = dataframes[18].drop(columns = col_drop)
x19 = dataframes[19].drop(columns = col_drop)
x20 = dataframes[20].drop(columns = col_drop)
x21 = dataframes[21].drop(columns = col_drop)
x22 = dataframes[22].drop(columns = col_drop)
x23 = dataframes[23].drop(columns = col_drop)
x24 = dataframes[24].drop(columns = col_drop)
x25 = dataframes[25].drop(columns = col_drop)
x26 = dataframes[26].drop(columns = col_drop)
x27 = dataframes[27].drop(columns = col_drop)
x28 = dataframes[28].drop(columns = col_drop)
x29 = dataframes[29].drop(columns = col_drop)
x30 = dataframes[30].drop(columns = col_drop)
x31 = dataframes[31].drop(columns = col_drop)
x32 = dataframes[32].drop(columns = col_drop)
x33 = dataframes[33].drop(columns = col_drop)
x34 = dataframes[34].drop(columns = col_drop)
x35 = dataframes[35].drop(columns = col_drop)
x36 = dataframes[36].drop(columns = col_drop)
x37 = dataframes[36].drop(columns = col_drop)
x38 = dataframes[36].drop(columns = col_drop)
x39 = dataframes[36].drop(columns = col_drop)
x40 = dataframes[40].drop(columns = col_drop)
x41 = dataframes[41].drop(columns = col_drop)
x42 = dataframes[42].drop(columns = col_drop)
x43 = dataframes[43].drop(columns = col_drop)
x44 = dataframes[44].drop(columns = col_drop)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-81a855064bd0> in <module>
# ----> 1 x0 = dataframes[0].drop(columns = col_drop)
#       2 x1 = dataframes[1].drop(columns = col_drop)
#       3 x2 = dataframes[2].drop(columns = col_drop)
#       4 x3 = dataframes[3].drop(columns = col_drop)
#       5 x4 = dataframes[4].drop(columns = col_drop)
#
# IndexError: list index out of range

# %%
x0.drop(x0[x0['To'] != 2020].index, inplace = True)
x1.drop(x1[x1['To'] != 2020].index, inplace = True)
x2.drop(x2[x2['To'] != 2020].index, inplace = True)
x3.drop(x3[x3['To'] != 2020].index, inplace = True)
x4.drop(x4[x4['To'] != 2020].index, inplace = True)
x5.drop(x5[x5['To'] != 2020].index, inplace = True)
x6.drop(x6[x6['To'] != 2020].index, inplace = True)
x7.drop(x7[x7['To'] != 2020].index, inplace = True)
x8.drop(x8[x8['To'] != 2020].index, inplace = True)
x9.drop(x9[x9['To'] != 2020].index, inplace = True)
x10.drop(x10[x10['To'] != 2020].index, inplace = True)
x11.drop(x11[x11['To'] != 2020].index, inplace = True)
x12.drop(x12[x12['To'] != 2020].index, inplace = True)
x13.drop(x13[x13['To'] != 2020].index, inplace = True)
x14.drop(x14[x14['To'] != 2020].index, inplace = True)
x15.drop(x15[x15['To'] != 2020].index, inplace = True)
x16.drop(x16[x16['To'] != 2020].index, inplace = True)
x17.drop(x17[x17['To'] != 2020].index, inplace = True)
x18.drop(x18[x18['To'] != 2020].index, inplace = True)
x19.drop(x19[x19['To'] != 2020].index, inplace = True)
x20.drop(x20[x20['To'] != 2020].index, inplace = True)
x21.drop(x21[x21['To'] != 2020].index, inplace = True)
x22.drop(x22[x22['To'] != 2020].index, inplace = True)
x23.drop(x23[x23['To'] != 2020].index, inplace = True)
x24.drop(x24[x24['To'] != 2020].index, inplace = True)
x25.drop(x25[x25['To'] != 2020].index, inplace = True)
x26.drop(x26[x26['To'] != 2020].index, inplace = True)
x27.drop(x27[x27['To'] != 2020].index, inplace = True)
x28.drop(x28[x28['To'] != 2020].index, inplace = True)
x29.drop(x29[x29['To'] != 2020].index, inplace = True)
x30.drop(x30[x30['To'] != 2020].index, inplace = True)
x31.drop(x31[x31['To'] != 2020].index, inplace = True)
x32.drop(x32[x32['To'] != 2020].index, inplace = True)
x33.drop(x33[x33['To'] != 2020].index, inplace = True)
x34.drop(x34[x34['To'] != 2020].index, inplace = True)
x35.drop(x35[x35['To'] != 2020].index, inplace = True)
x36.drop(x36[x36['To'] != 2020].index, inplace = True)
x37.drop(x37[x37['To'] != 2020].index, inplace = True)
x38.drop(x38[x38['To'] != 2020].index, inplace = True)
x39.drop(x39[x39['To'] != 2020].index, inplace = True)
x40.drop(x40[x40['To'] != 2020].index, inplace = True)
x41.drop(x41[x41['To'] != 2020].index, inplace = True)
x42.drop(x42[x42['To'] != 2020].index, inplace = True)
x43.drop(x43[x43['To'] != 2020].index, inplace = True)
x44.drop(x44[x44['To'] != 2020].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7d73a8a4f0f4> in <module>
# ----> 1 x0.drop(x0[x0['To'] != 2020].index, inplace = True)
#       2 x1.drop(x1[x1['To'] != 2020].index, inplace = True)
#       3 x2.drop(x2[x2['To'] != 2020].index, inplace = True)
#       4 x3.drop(x3[x3['To'] != 2020].index, inplace = True)
#       5 x4.drop(x4[x4['To'] != 2020].index, inplace = True)
#
# NameError: name 'x0' is not defined

# %%
state_keys = ['Alabama',
          'Arizona',
          'Arkansas',
          'California',
          'Colorado',
          'Connecticut',
          'Delaware',
          'District of Columbia',
          'Florida',
          'Georgia',
          'Hawaii',
          'Idaho',
          'Illinois',
          'Indiana',
          'Iowa',
          'Kansas',
          'Kentucky',
          'Louisiana',
          'Maine',
          'Maryland',
          'Massachusetts',
          'Michigan',
          'Minnesota',
          'Mississippi',
          'Missouri',
          'Montana',
          'Nebraska',
          'Nevada',
          'New Jersey',
          'New York',
          'North Carolina',
          'North Dakota',
          'Ohio',
          'Oklahoma',
          'Oregon',
          'Pennsylvania',
          'South Carolina',
          'Tennessee',
          'Texas',
          'Utah',
          'Virginia',
          'Washington',
          'West Virginia',
          'Wisconsin',
          'Wyoming']

# %%
list_x = [x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,x28,x29,x30,x31,x32,x33,x34,x35,x36,x37,x38,x39,x40,x41,x42,x43,x44]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7638f99c40c2> in <module>
# ----> 1 list_x = [x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,x28,x29,x30,x31,x32,x33,x34,x35,x36,x37,x38,x39,x40,x41,x42,x43,x44]
#
# NameError: name 'x0' is not defined

# %%
dic = {} 
for key in state_keys: 
    for value in list_x: 
        dic[key] = value 
        list_x.remove(value) 
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-11763195b0e2> in <module>
#       1 dic = {}
#       2 for key in state_keys:
# ----> 3     for value in list_x:
#       4         dic[key] = value
#       5         list_x.remove(value)
#
# NameError: name 'list_x' is not defined

# %%
dic
# Out:
# {'Alabama':                        Player    To         Date        City
#  4      Eric Bledsoe\bledser01  2020   Dec 9 1989  Birmingham
#  8   DeMarre Carroll\carrode01  2020  Jul 27 1986  Birmingham
#  23   JaMychal Green\greenja01  2020  Jun 21 1990  Montgomery
#  25        Donta Hall\halldo01  2020   Aug 7 1997     Luverne
#  46     Josh Magette\magetjo01  2020  Nov 28 1989  Birmingham,
#  'Arizona':                         Player    To         Date        City
#  1      Marvin Bagley\baglema01  2020  Mar 14 1999       Tempe
#  3     Zylan Cheatham\cheatzy01  2020  Nov 17 1995     Phoenix
#  9          Kevin Knox\knoxke01  2020  Aug 11 1999     Phoenix
#  14  Matisse Thybulle\thybuma01  2020   Mar 4 1997  Scottsdale
#  15       Paul Watson\watsopa01  2020  Dec 30 1994     Phoenix,
#  'Arkansas':                       Player    To         Date          City
#  11     Mike Conley\conlemi01  2020  Oct 11 1987  Fayetteville
# ...
