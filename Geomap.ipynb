# %%
# Dependencies (maybe too much lol) 
#yeah you right -Saburo
import requests
import json
import pandas as pd
import numpy as np
import gmaps
import time
from us import states
from scipy.stats import linregress
from matplotlib import pyplot as plt
from config import gkey
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0a7775b64dce> in <module>
#      10 from scipy.stats import linregress
#      11 from matplotlib import pyplot as plt
# ---> 12 from config import gkey
#
# ModuleNotFoundError: No module named 'config'

# %%
birthplace = pd.read_csv("../Research Data/birth_dataframe.csv", encoding = "utf8")
birthplace.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-fa0d0df3b788> in <module>
# ----> 1 birthplace = pd.read_csv("../Research Data/birth_dataframe.csv", encoding = "utf8")
#       2 birthplace.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
salaries = pd.read_csv("../Research Data/NBAsalaries.csv", encoding = "utf8")
salaries.head()
# Out:
#               Player   2019-20
# 0       A.J. Hammons    350087
# 1       Aaron Gordon  19863636
# 2      Aaron Holiday   2239200
# 3        Abdel Nader   1618520
# 4  Admiral Schofield    898310

# %%
state_med_income = pd.read_csv("../Research Data/State_median_income.csv", encoding = "utf8")
state_med_income["State"] = state_med_income["Name"]
state_med_income.head()
# Out:
#    State FIPS Code Postal Code           Name Poverty Estimate, All Ages  \
# 0                0          US  United States                 41,852,315
# 1                1          AL        Alabama                    801,758
# 2                2          AK         Alaska                     80,224
# 3                4          AZ        Arizona                    990,291
# 4                5          AR       Arkansas                    492,306
#
#   90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 0         41,619,366         42,085,264                       13.1
# 1            785,668            817,848                       16.8
# 2             76,253             84,195                       11.1
# 3            970,614          1,009,968                       14.1
# 4            478,253            506,359                       16.8
#
#    90% CI Lower Bound.1  90% CI Upper Bound.1 Poverty Estimate, Age 0-17  ...  \
# ...

# %%
combined = pd.merge(birthplace, salaries, how = "inner", on = "Player")
combined
# Out:
#                Player         Date           City       State   2019-20
# 0        Aaron Gordon  Sep 16 1995       San Jose  California  19863636
# 1       Aaron Holiday  Sep 30 1996         Ruston   Louisiana   2239200
# 2          Alec Burks  Jul 20 1991      Grandview    Missouri   2320044
# 3     Al-Farouq Aminu  Sep 21 1990        Atlanta     Georgia   9258000
# 4    Alfonzo McKinnie  Sep 17 1992        Chicago    Illinois   1361046
# ..                ...          ...            ...         ...       ...
# 291   Wilson Chandler  May 10 1987  Benton Harbor    Michigan   2564753
# 292      Yogi Ferrell   May 9 1993   Indianapolis     Indiana   3150000
# 293      Zach Collins  Nov 19 1997      Las Vegas      Nevada   4240200
# 294       Zach LaVine  Mar 10 1995         Renton  Washington  19500000
# 295      Zach Norvell   Dec 9 1997        Chicago    Illinois     50752
#
# [296 rows x 5 columns]

# %%
combined_1 = pd.merge(combined, state_med_income, how = "inner", on = "State")
headers = list(combined_1.columns.values)
headers.remove('Player')
headers.remove('City')
headers.remove('State')
headers.remove('2019-20')
headers.remove('Poverty Percent, All Ages')

geo_df = combined_1.drop(columns = headers)
geo_df
# Out:
#                  Player             City        State   2019-20  \
# 0          Aaron Gordon         San Jose   California  19863636
# 1          Allen Crabbe      Los Angeles   California  17818456
# 2         Austin Rivers     Santa Monica   California   2174318
# 3           Brook Lopez  North Hollywood   California  12093024
# 4    Chandler Hutchison    Mission Viejo   California   2332320
# ..                  ...              ...          ...       ...
# 291           Kris Dunn       New London  Connecticut   5348007
# 292         Rodney Hood         Meridian  Mississippi   5718000
# 293       Terence Davis        Southaven  Mississippi    898310
# 294      Troy Brown Jr.        Las Vegas       Nevada   3219480
# 295        Zach Collins        Las Vegas       Nevada   4240200
#
#      Poverty Percent, All Ages
# 0                         12.8
# 1                         12.8
# 2                         12.8
# 3                         12.8
# 4                         12.8
# ...
